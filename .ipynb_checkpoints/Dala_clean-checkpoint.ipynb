# %%
import pandas as pd 
import numpy 
import dask
import spacy 
import nltk

# %%
from dask.distributed import Client , progress
c=Client()
c
# Out:
# <Client: 'tcp://127.0.0.1:51134' processes=4 threads=4, memory=19.85 GiB>
